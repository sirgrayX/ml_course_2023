# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_all = pd.read_excel('../data/Data/dataset.xlsx', names=[
    'название', 'описание'] + sum([[f'компетенция {col}', f'значимость {col}', f'содержание компетенции {col}'] \
                                   for col in range(1, 11)], []))
data_all.head(5)
# Out:
#                                   название  \
# 0  Разработка мобильных приложений(юниоры)
# 1           Преподавание в младших классах
# 2            Дошкольное воспитание(юниоры)
# 3                    Дошкольное воспитание
# 4   Преподавание в младших классах(юниоры)
#
#                                             описание  \
# 0  Смартфоны продаются и продажи только растут. К...
# 1  Высококвалифицированные специалисты в сфере на...
# 2   Воспитатель детей дошкольного возраста осущес...
# 3  Воспитатель детей дошкольного возраста осущест...
# 4  Высококвалифицированные специалисты в сфере на...
#
#                                        компетенция 1 значимость 1  \
# 0                   Организация и управление работой            5
# 1                            Общекультурное развитие           10
# 2  Соблюдение санитарных норм и правил профилакти...           16
# 3  Соблюдение санитарных норм и правил профилакти...           16
# 4                            Общекультурное развитие           10
#
#                             содержание компетенции 1  \
# 0  Специалист должен знать и понимать: • Принципы...
# 1  Специалист должен знать и понимать:\n• Основы ...
# 2  Специалист должен знать и понимать:\n• Стандар...
# 3  Специалист должен знать и понимать: • Стандарт...
# 4  Специалист должен знать и понимать: • Основы я...
#
#                                        компетенция 2 значимость 2  \
# 0  Решение проблем, инновационность и инициативность            5
# 1  Культура безопасного труда Организация рабочег...            5
# 2  Поиск, анализ и оценка информации, необходимой...           24
# 3  Поиск, анализ и оценка информации, необходимой...           24
# 4  Культура безопасного труда Организация рабочег...            5
#
#                             содержание компетенции 2  \
# 0  Специалист должен знать и понимать: • Общие ти...
# 1  Специалист должен знать и понимать: Участник к...
# 2  Специалист должен знать и понимать: • основную...
# 3  Специалист должен знать и понимать:\n• основну...
# 4  Специалист должен знать и понимать: Участник к...
#
#                                        компетенция 3 значимость 3  ...  \
# 0      Анализ и проектирование мобильного приложения           30  ...
# 1                      Общепрофессиональное развитие           40  ...
# 2  Использование информационно-коммуникационных т...            6  ...
# 3  Использование информационно-коммуникационных т...            6  ...
# 4                      Общепрофессиональное развитие           40  ...
#
#   содержание компетенции 7 компетенция 8 значимость 8  \
# 0                      NaN           NaN          NaN
# 1                      NaN           NaN          NaN
# 2                      NaN           NaN          NaN
# 3                      NaN           NaN          NaN
# 4                      NaN           NaN          NaN
#
#   содержание компетенции 8 компетенция 9 значимость 9  \
# 0                      NaN           NaN          NaN
# 1                      NaN           NaN          NaN
# 2                      NaN           NaN          NaN
# 3                      NaN           NaN          NaN
# 4                      NaN           NaN          NaN
#
#   содержание компетенции 9 компетенция 10  значимость 10  \
# 0                      NaN            NaN            NaN
# 1                      NaN            NaN            NaN
# 2                      NaN            NaN            NaN
# 3                      NaN            NaN            NaN
# 4                      NaN            NaN            NaN
#
#   содержание компетенции 10
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 32 columns]

# %%
data_all.shape
# Out:
# (129, 32)

# %% [markdown]
# 129 строк, в каждой из которых приведено описание компетенций, и 32 столбца, в каждом из которых приводится часть описания компетенции.

# %%
data_all.iloc[0]
# Out:
# название                               Разработка мобильных приложений(юниоры)
# описание                     Смартфоны продаются и продажи только растут. К...
# компетенция 1                                 Организация и управление работой
# значимость 1                                                                 5
# содержание компетенции 1     Специалист должен знать и понимать: • Принципы...
# компетенция 2                Решение проблем, инновационность и инициативность
# значимость 2                                                                 5
# содержание компетенции 2     Специалист должен знать и понимать: • Общие ти...
# компетенция 3                    Анализ и проектирование мобильного приложения
# значимость 3                                                                30
# содержание компетенции 3     Специалист должен знать и понимать: • Важность...
# компетенция 4                                  Разработка мобильных приложений
# значимость 4                                                                50
# содержание компетенции 4     Специалист должен знать и понимать: • Важность...
# компетенция 5                          \n \nТестирование мобильных приложений
# значимость 5                                                                10
# содержание компетенции 5     Специалист должен знать и понимать: • Устранен...
# компетенция 6                                                              NaN
# значимость 6                                                               NaN
# содержание компетенции 6                                                   NaN
# компетенция 7                                                              NaN
# значимость 7                                                               NaN
# содержание компетенции 7                                                   NaN
# компетенция 8                                                              NaN
# значимость 8                                                               NaN
# содержание компетенции 8                                                   NaN
# компетенция 9                                                              NaN
# значимость 9                                                               NaN
# содержание компетенции 9                                                   NaN
# компетенция 10                                                             NaN
# значимость 10                                                              NaN
# содержание компетенции 10                                                  NaN
# Name: 0, dtype: object

# %%
# пропуски
data_all.isnull().sum() / len(data_all) * 100
# Out:
# название                      0.000000
# описание                      0.000000
# компетенция 1                 0.000000
# значимость 1                  0.775194
# содержание компетенции 1      0.000000
# компетенция 2                 0.000000
# значимость 2                  0.775194
# содержание компетенции 2      0.000000
# компетенция 3                 0.775194
# значимость 3                  0.775194
# содержание компетенции 3      0.775194
# компетенция 4                 3.875969
# значимость 4                  3.875969
# содержание компетенции 4      3.875969
# компетенция 5                 8.527132
# значимость 5                  9.302326
# содержание компетенции 5      9.302326
# компетенция 6                25.581395
# значимость 6                 26.356589
# содержание компетенции 6     26.356589
# компетенция 7                53.488372
# значимость 7                 53.488372
# содержание компетенции 7     54.263566
# компетенция 8                82.945736
# значимость 8                 82.945736
# содержание компетенции 8     82.945736
# компетенция 9                90.697674
# значимость 9                 90.697674
# содержание компетенции 9     90.697674
# компетенция 10               95.348837
# значимость 10                96.899225
# содержание компетенции 10    96.899225
# dtype: float64

# %%
data_all[~data_all['компетенция 10'].isnull()]
# Out:
#                                  название  \
# 14  Информационные кабельные сети(юниоры)
# 39      Командная работа на производстве
# 55                     Ландшафтный дизайн
# 56            Ландшафтный дизайн (Юниоры)
# 95                    Предпринимательство
# 96           Предпринимательство (Юниоры)
#
#                                              описание  \
# 14  Сегодня более 70% аварийных ситуаций на телеко...
# 39  Соревнование по командной работе на производст...
# 55  Вид соревнований: Командные соревнования, в со...
# 56  Вид соревнований: Командные соревнования, в со...
# 95  Это командные соревнования (в каждой команде д...
# 96  Это командные соревнования (в каждой команде д...
#
#                                    компетенция 1 значимость 1  \
# 14                             Организация работ            5
# 39             Организация и управление работой            10
# 55  Организация и управление рабочими процессами           10
# 56  Организация и управление рабочими процессами           11
# 95                                   Бизнес-план            8
# 96                                   Бизнес-план            8
#
#                              содержание компетенции 1  \
# 14  Специалист должен знать и понимать:  Законода...
# 39  Специалист должен знать и понимать: ❖ принципы...
# 55  Специалист должен знать и понимать: принципы п...
# 56  Специалист должен знать и понимать: принципы п...
# 95  Специалист должен знать и понимать: ● роль и з...
# 96  Специалист должен знать и понимать: ● роль и з...
#
#                                 компетенция 2 значимость 2  \
# 14                    Коммуникативные навыки             5
# 39  Навыки общения и межличностных отношений             5
# 55   Навыки коммуникации и работы с клиентами            5
# 56   Навыки коммуникации и работы с клиентами            6
# 95                         Организация работы            5
# 96                         Организация работы            5
#
#                              содержание компетенции 2  \
# 14  Специалист должен знать и понимать:  Важность...
# 39  Специалист должен знать и понимать:   ❖ спектр...
# 55  Специалист должен знать и понимать: важность у...
# 56  Специалист должен знать и понимать: важность у...
# 95  Специалист должен знать и понимать: ● значение...
# 96  Специалист должен знать и понимать: ● значение...
#
#                                         компетенция 3 значимость 3  ...  \
# 14                     Планирование и проектирование             5  ...
# 39               Проектирование и реализация проекта            10  ...
# 55  Проектирование зеленых насаждений и интерпрета...           15  ...
# 56  Проектирование зеленых насаждений и интерпрета...           16  ...
# 95  Формирование навыков коллективной работы и упр...            5  ...
# 96  Формирование навыков коллективной работы и упр...            5  ...
#
#                              содержание компетенции 7  \
# 14  Специалист должен знать и понимать:  Стандарт...
# 39  Специалист должен знать и понимать:   ❖ принци...
# 55  Специалист должен знать и понимать:\nклассифик...
# 56  Специалист должен знать и понимать:\nклассифик...
# 95  Специалист должен знать и понимать: ● преимуще...
# 96  Специалист должен знать и понимать: ● преимуще...
#
#                                         компетенция 8 значимость 8  \
# 14                 Поиск и устранение неисправностей          10.0
# 39                              Сварочные технологии          10.0
# 55  Садовые технологии (водопровод и канализация,\...          5.0
# 56  Садовые технологии (водопровод и канализация,\...          6.0
# 95                             Финансовые инструменты         10.0
# 96                             Финансовые инструменты         10.0
#
#                              содержание компетенции 8  \
# 14  Специалист должен знать и понимать:  Этапы оп...
# 39  Специалист должен знать и понимать: ❖ Специфич...
# 55  Специалист должен знать и понимать:\nпринципы ...
# 56  Специалист должен знать и понимать:\nпринципы ...
# 95  Специалист должен знать и понимать: ● необходи...
# 96  Специалист должен знать и понимать: ● необходи...
#
#                 компетенция 9 значимость 9  \
# 14                  Измерения         15.0
# 39          Сборочные работы          15.0
# 55                    Водоемы          5.0
# 56                    Водоемы          6.0
# 95  Продвижение фирмы/проекта         15.0
# 96  Продвижение фирмы/проекта         15.0
#
#                              содержание компетенции 9  \
# 14  Специалист должен знать и понимать:  Принципы...
# 39  Специалист должен знать и понимать:  ❖ принцип...
# 55  Специалист должен знать и понимать: различные ...
# 56  Специалист должен знать и понимать: различные ...
# 95  Специалист должен знать и понимать: ● значимос...
# 96  Специалист должен знать и понимать: ● значимос...
#
#                                        компетенция 10  значимость 10  \
# 14   Инспектировать и чистить разъёмные соединени...         Всего
# 39                   Испытания и ввод в эксплуатацию              10
# 55  обеспечить постоянный уход и обслуживание для ...            NaN
# 56  обеспечить постоянный уход и обслуживание для ...            NaN
# 95                               Презентация компании              5
# 96                               Презентация компании              5
#
#                             содержание компетенции 10
# 14                                                100
# 39  Специалист должен знать и понимать:  ❖ критери...
# 55                                                NaN
# 56                                                NaN
# 95  Специалист должен знать и понимать:  ● важност...
# 96  Специалист должен знать и понимать:  ● важност...
#
# [6 rows x 32 columns]

# %% [markdown]
# Анкета, приведённая в примере, $-$ это образец тех данных, которые будет принимать на вход итоговая система. Нужно обратить внимание, что в анкете представлены группы навыков и показатель их важности в процентном соотношении.
#
# Необходимо выделить такие группы в наших данных.

# %%
len(data_all['название'].unique())
# Out:
# 128

# %% [markdown]
# Сколько записей в базе $-$ столько и уникальных компетенций. Необходимо разделить на кластеры.
